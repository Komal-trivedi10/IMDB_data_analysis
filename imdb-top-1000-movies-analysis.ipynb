# %%
import numpy as np  
import pandas as pd


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/imdb-dataset-of-top-1000-movies-and-tv-shows/imdb_top_1000.csv

# %%
df = pd.read_csv('/kaggle/input/imdb-dataset-of-top-1000-movies-and-tv-shows/imdb_top_1000.csv')

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# 1. Top 5 movies interms of their IMDB ratings?

# %%
for Series_Title in df.head()['Series_Title'].values:
    print(Series_Title)
# Out:
# The Shawshank Redemption
# The Godfather
# The Dark Knight
# The Godfather: Part II
# 12 Angry Men

# %% [markdown]
# 2. Top 5 most voted movies?

# %%
for Series_Title in df.sort_values(by='No_of_Votes',ascending=False).head()['Series_Title'].values:
    print(Series_Title)
# Out:
# The Shawshank Redemption
# The Dark Knight
# Inception
# Fight Club
# Pulp Fiction

# %%
for Series_Title in df.sort_values(by='Released_Year',ascending=True).head()['Series_Title'].values:
    print(Series_Title)
# Out:
# Das Cabinet des Dr. Caligari
# The Kid
# Nosferatu
# Sherlock Jr.
# The Gold Rush

# %%
df.sort_values(by='Released_Year',ascending=True).head()
# Out:
#                                            Poster_Link  \
# 321  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 127  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 568  https://m.media-amazon.com/images/M/MV5BMTAxYj...
# 194  https://m.media-amazon.com/images/M/MV5BZWFhOG...
# 193  https://m.media-amazon.com/images/M/MV5BZjEyOT...
#
#                      Series_Title Released_Year Certificate Runtime  \
# 321  Das Cabinet des Dr. Caligari          1920         NaN  76 min
# 127                       The Kid          1921      Passed  68 min
# 568                     Nosferatu          1922         NaN  94 min
# 194                  Sherlock Jr.          1924      Passed  45 min
# 193                 The Gold Rush          1925      Passed  95 min
#
#                         Genre  IMDB_Rating  \
# 321  Fantasy, Horror, Mystery          8.1
# 127     Comedy, Drama, Family          8.3
# 568           Fantasy, Horror          7.9
# 194   Action, Comedy, Romance          8.2
# ...

# %% [markdown]
# No. of movies in drama genre

# %%
c=0
for Genre in df['Genre']:
    if(Genre=='Drama'):
        c+=1
print(c)
# Out:
# 85

# %% [markdown]
# Genres

# %%
df['Genre'].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Action, Adventure, Sci-Fi', 'Drama, Romance', 'Western',
#        'Action, Sci-Fi', 'Biography, Crime, Drama',
#        'Action, Adventure, Fantasy', 'Comedy, Drama, Thriller',
#        'Adventure, Drama, Sci-Fi', 'Animation, Adventure, Family',
#        'Drama, War', 'Crime, Drama, Fantasy', 'Comedy, Drama, Romance',
#        'Crime, Drama, Mystery', 'Crime, Drama, Thriller',
#        'Action, Drama, Mystery', 'Drama, Family, Fantasy', 'Drama, Music',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Sci-Fi',
#        'Biography, Drama, Music', 'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Animation, Drama, War',
#        'Adventure, Comedy, Sci-Fi', 'Horror, Mystery, Thriller',
#        'Drama, Romance, War', 'Comedy, Drama, Family',
#        'Animation, Drama, Fantasy', 'Action, Biography, Drama',
# ...

# %% [markdown]
# No. of unique genre

# %%
Genre=[]
for i in df['Genre']:
    Genre+=i.split(',')
unique_gn=list(set(Genre))
unique_gn
# Out:
# [' Adventure',
#  ' Crime',
#  ' Sport',
#  'Crime',
#  'Thriller',
#  ' History',
#  ' Sci-Fi',
#  ' Horror',
#  ' War',
#  'Animation',
#  'Film-Noir',
#  ' Music',
#  'Comedy',
#  ' Film-Noir',
#  'Family',
#  ' Western',
#  'Adventure',
#  ' Family',
#  ' Mystery',
#  ' Romance',
#  'Western',
#  ' Biography',
#  'Fantasy',
#  ' Action',
#  'Action',
#  'Mystery',
#  ' Musical',
#  'Drama',
#  ' Comedy',
#  ' Thriller',
#  ' Fantasy',
#  'Biography',
#  ' Drama',
#  'Horror']

# %% [markdown]
# No. of movies in different genre

# %%
Genre=[]
for i in df['Genre']:
    Genre+=i.split(',')
unique_gn=list(set(Genre))

# %%
for gn in unique_gn:
    c=0
    for Genre in df['Genre']:
        if(gn in Genre):
            c+=1
    print(gn,c)
# Out:
#  Adventure 124
#  Crime 102
#  Sport 19
# Crime 209
# Thriller 137
#  History 56
#  Sci-Fi 67
#  Horror 21
#  War 51
# Animation 82
# Film-Noir 19
#  Music 47
# Comedy 233
#  Film-Noir 16
# Family 56
#  Western 16
# Adventure 196
#  Family 54
#  Mystery 87
#  Romance 125
# Western 20
#  Biography 21
# Fantasy 66
#  Action 17
# Action 189
# Mystery 99
#  Musical 17
# Drama 724
#  Comedy 78
#  Thriller 136
#  Fantasy 64
# Biography 109
#  Drama 435
# Horror 32

# %% [markdown]
# Comedy movies

# %%
df[df['Genre']=='Comedy']
# Out:
#                                            Poster_Link  \
# 78   https://m.media-amazon.com/images/M/MV5BZWI3ZT...
# 277  https://m.media-amazon.com/images/M/MV5BMzAwNj...
# 417  https://m.media-amazon.com/images/M/MV5BMTEwNj...
# 539  https://m.media-amazon.com/images/M/MV5BYzQ5Nj...
# 679  https://m.media-amazon.com/images/M/MV5BMDA0Nj...
# 750  https://m.media-amazon.com/images/M/MV5BNGQwZj...
# 800  https://m.media-amazon.com/images/M/MV5BOTA5Mz...
# 808  https://m.media-amazon.com/images/M/MV5BZjFkOW...
# 816  https://m.media-amazon.com/images/M/MV5BNzE1Nj...
# 837  https://m.media-amazon.com/images/M/MV5BMGUwMj...
# 842  https://m.media-amazon.com/images/M/MV5BZjA3Yj...
# 855  https://m.media-amazon.com/images/M/MV5BZDVhNz...
# 969  https://m.media-amazon.com/images/M/MV5BMTM5MD...
#
#                                           Series_Title Released_Year  \
# 78   Dr. Strangelove or: How I Learned to Stop Worr...          1964
# ...

# %% [markdown]
# unique Genre

# %%
unique_gn
# Out:
# [' Adventure',
#  ' Crime',
#  ' Sport',
#  'Crime',
#  'Thriller',
#  ' History',
#  ' Sci-Fi',
#  ' Horror',
#  ' War',
#  'Animation',
#  'Film-Noir',
#  ' Music',
#  'Comedy',
#  ' Film-Noir',
#  'Family',
#  ' Western',
#  'Adventure',
#  ' Family',
#  ' Mystery',
#  ' Romance',
#  'Western',
#  ' Biography',
#  'Fantasy',
#  ' Action',
#  'Action',
#  'Mystery',
#  ' Musical',
#  'Drama',
#  ' Comedy',
#  ' Thriller',
#  ' Fantasy',
#  'Biography',
#  ' Drama',
#  'Horror']
